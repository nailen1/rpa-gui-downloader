# %%
import pyautogui
from pyautogui import *
import time
from time import sleep as ____sleep

# %%
screen_width, screen_height = size()

# %%
time_duration = 0.25
time_interval_s = 0.25
time_interval = 0.50
time_interval_l = 1

# %%
moveTo(100, 100, duration=0.25)

# %%
cposition()
# Out:
# Point(x=100, y=34)

# %%
# coordinates
# reference screen size: left-half 
coord_bos_home_input_menu = Point(x=1038, y=42)
coord_bos_home_menu_name = Point(x=1018, y=77)
coord_bos_home_go = Point(x=1099, y=38)
coord_8186_input_start_date = Point(x=137, y=173)
coord_8186_input_end_date = Point(x=319, y=176)
coord_8186_input_fund_code = Point(x=505, y=169)
coord_8186_fund_go = Point(x=540, y=173)
coord_8186_fund_popup_checkbox = Point(x=258, y=604)
coord_8186_fund_popup_confirm = Point(x=620, y=1078)
coord_8186_search_go = Point(x=1168, y=126)
coord_8186_excel_go = Point(x=1240, y=240)
coord_home_logo = Point(x=100, y=34)

# %%
# input_values
menu_code = '8186'
start_date = '20210101'
end_date = '20231031'
fund_code = '100004'

# %%
click(coord_bos_home_input_menu)
time.sleep(time_interval)
hotkey('ctrl', 'a')
press('backspace')
time.sleep(time_interval)
typewrite(menu_code)
time.sleep(time_interval)
click(coord_bos_home_menu_name)
time.sleep(time_interval)
click(coord_bos_home_go)
time.sleep(time_interval)

# %%
def control_from_home_to_menu(menu_code):
    click(coord_bos_home_input_menu)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(menu_code))
    time.sleep(time_interval)
    click(coord_bos_home_menu_name)
    time.sleep(time_interval)
    click(coord_bos_home_go)
    time.sleep(time_interval)

# %%
click(coord_8186_input_start_date)
time.sleep(time_interval)
hotkey('ctrl', 'a')
press('backspace')
time.sleep(time_interval)
typewrite(list(start_date))
time.sleep(time_interval)
click(coord_8186_input_end_date)
hotkey('ctrl', 'a')
press('backspace')
time.sleep(time_interval)
typewrite(list(end_date))
time.sleep(time_interval)
click(coord_8186_input_fund_code)
hotkey('ctrl', 'a')
press('backspace')
time.sleep(time_interval)
typewrite(fund_code)
time.sleep(time_interval)
click(coord_8186_fund_go)
time.sleep(time_interval)

# %%
def control_on_8186_to_fund_popup(start_date, end_date, fund_code):
    click(coord_8186_input_start_date)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(start_date))
    time.sleep(time_interval)
    click(coord_8186_input_end_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(end_date))
    time.sleep(time_interval)
    click(coord_8186_input_fund_code)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(fund_code)
    time.sleep(time_interval)
    click(coord_8186_fund_go)
    time.sleep(time_interval)

# %%
def wait_for_loading_to_disappear(loading_image, timeout=300):
    """
    loading_image: 로딩 화면의 스크린샷 파일 경로 (예: 'loading.png')
    timeout: 함수가 지정한 시간(초) 동안 로딩 화면이 사라지지 않으면 중단 (기본값: 5분)
    """
    start_time = time.time()
    
    while True:
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print("Timeout! Loading screen did not disappear within the specified time.")
            return False
        
        # locateOnScreen 함수를 사용하여 로딩 화면이 화면에 있는지 확인
        location = pyautogui.locateOnScreen(loading_image, confidence=0.8)
        if location is None:
            return True
        
        # 로딩 화면이 화면에 있으면 잠시 대기 후 다시 확인
        time.sleep(1)

# %%
wait_for_loading_to_disappear('image-8186-loading.png', timeout=100)
# Out:
# True

# %%
time.sleep(time_interval)
click(coord_8186_fund_popup_checkbox)
time.sleep(time_interval)
click(coord_8186_fund_popup_confirm)
time.sleep(time_interval)
click(coord_8186_search_go)
time.sleep(time_interval)
# 로딩 화면이 사라질 때까지 기다린다.
if wait_for_loading_to_disappear('image-8186-loading.png'):
    # 로딩 화면이 사라지면 특정 좌표를 클릭
    pyautogui.click(coord_8186_excel_go)

# %%
def control_on_fund_popup():
    time.sleep(time_interval)
    click(coord_8186_fund_popup_checkbox)
    time.sleep(time_interval)
    click(coord_8186_fund_popup_confirm)

# %%
def control_on_8186_to_excel():
    time.sleep(time_interval)
    click(coord_8186_search_go)
    time.sleep(time_interval)
    # 로딩 화면이 사라질 때까지 기다린다.
    if wait_for_loading_to_disappear('image-8186-loading.png'):
        # 로딩 화면이 사라지면 특정 좌표를 클릭
        pyautogui.click(coord_8186_excel_go)

# %%
import cv2

# %%
cv2
# Out:
# <module 'cv2' from 'c:\\Users\\danie\\anaconda3\\lib\\site-packages\\cv2\\__init__.py'>

# %%
# 찾아보기 클릭 후 바로 파일이름 타이핑, 탭 누르고, c 누르고, 엔터 뉼러서 저장됨
# 그냥 엑셀 화면에서 F12 누르면 됨(윈도우 기준) > 파일이름 타이핑 > 탭 > c > 경로이미지클릭 > C:\rpa-download-datasets > 엔터

# %%
import pyautogui

def click_image(image_path, confidence_level=0.8, timeout=10):
    """
    image_path: 찾고자 하는 이미지의 파일 경로
    confidence_level: 이미지 탐색 정확도 (0 ~ 1 사이의 값)
    timeout: 이미지 탐색 최대 대기 시간 (초)
    
    이미지를 찾으면 그 위치를 클릭하고 True를 반환하고, 찾지 못하면 False를 반환한다.
    """
    start_time = time.time()
    while True:
        location = pyautogui.locateCenterOnScreen(image_path, confidence=confidence_level)
        if location:
            pyautogui.click(location)
            return True
        
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print(f"Timeout! Could not find the image '{image_path}' within {timeout} seconds.")
            return False
        
        time.sleep(1)

def moveTo_image(image_path, confidence_level=0.8, timeout=10):
    """
    image_path: 찾고자 하는 이미지의 파일 경로
    confidence_level: 이미지 탐색 정확도 (0 ~ 1 사이의 값)
    timeout: 이미지 탐색 최대 대기 시간 (초)
    
    이미지를 찾으면 그 위치를 클릭하고 True를 반환하고, 찾지 못하면 False를 반환한다.
    """
    start_time = time.time()
    while True:
        location = pyautogui.locateCenterOnScreen(image_path, confidence=confidence_level)
        if location:
            pyautogui.moveTo(location)
            return True
        
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print(f"Timeout! Could not find the image '{image_path}' within {timeout} seconds.")
            return False
        
        time.sleep(1)

# %%
moveTo_image('excel-folder-path-arrows.png')
# Out:
# True

# %%
import datetime

# %%
file_name
# Out:
# 'menu8186-code100004-save20231101.csv'

# %%
time.sleep(5)
press('F12')
time.sleep(time_interval_l)
typewrite(file_name)
time.sleep(time_interval)
press('tab')
time.sleep(time_interval)
typewrite(file_format_select_key)
time.sleep(time_interval)
moveTo_image('excel-folder-path-arrows.png')
time.sleep(time_interval_l)
move(screen_width/4,0)
click()
time.sleep(time_interval_l)
typewrite(file_path)
time.sleep(time_interval_l)
hotkey('alt', 's')
time.sleep(time_interval)

# %%
def control_on_excel_to_save(file_path, file_name):
    time.sleep(5)
    press('F12')
    time.sleep(time_interval_l)
    typewrite(file_name)
    time.sleep(time_interval)
    press('tab')
    time.sleep(time_interval)
    typewrite(file_format_select_key)
    time.sleep(time_interval)
    moveTo_image('excel-folder-path-arrows.png')
    time.sleep(time_interval_l)
    move(screen_width/5,0)
    click()
    time.sleep(time_interval_l)
    typewrite(file_path)
    time.sleep(time_interval_l)
    hotkey('alt', 's')
    time.sleep(time_interval)

# %%
position()
# Out:
# Point(x=1033, y=367)

# %%
def control_on_2160_to_set_inputs(fund_code, start_date, end_date):
    print(f'- step: open fund popup.')
    click(coord_2160_input_fund_code)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(fund_code))

    time.sleep(time_interval)
    click(coord_2160_input_start_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(start_date))
    
    time.sleep(time_interval)
    click(coord_2160_input_end_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(end_date))

    time.sleep(time_interval)
    click(coord_2160_search_go)
    time.sleep(time_interval_l)

def control_on_2160_to_excel():
    print(f'- step: click excel download button.')
    time.sleep(time_interval)
    click(coord_2160_search_go)
    time.sleep(time_interval_l)
        # 로딩 화면이 사라질 때까지 기다린다.
    if wait_for_loading_to_disappear('image-8186-loading.png'):
    # 로딩 화면이 사라지면 특정 좌표를 클릭
        print(f'- step: execute Excel.')
        click(coord_2160_excel_go)
        time.sleep(time_interval_l)
        click(coord_excel_format_popup_button)
    time.sleep(time_interval_loading)
    time.sleep(30)

# %%
control_on_2160_to_set_inputs('100004', '20210101', '20231031')
# Out:
# - step: open fund popup.

# %%
control_on_2160_to_excel()
# Out:
# - step: click excel download button.
# - step: execute Excel.

# %%
position()
# Out:
# Point(x=1035, y=464)

# %%
moveTo(coord_2205_input_fund_code)

# %%
import datetime
import os
import pyautogui
from pyautogui import *
import time
from time import sleep as ____sleep

# october constants
fund_codes_october = [
    "000051", "000052", "100001", "100004", "100008", "100019", "100030",
    "100038", "100042", "100050", "100056", "100059", "100060", "100065",
    "100066", "100069", "100073", "100077", "100078", "100079", "805701",
    "805702", "805703", "805704", "A00001", "A00002", "A00003", "A00004", "A00005"
]
start_date_default = '20210101'
end_date_october = '20231031'


# global constants
time_duration = 0.25
time_interval_s = 0.25
time_interval = 0.50
time_interval_l = 1
time_interval_loading = 5
time_cooldown = 10

# coordinate constants
# reference screen size: left-half 
screen_width, screen_height = size()
coord_home_input_menu = Point(x=1038, y=42)
coord_home_menu_name = Point(x=1018, y=77)
coord_bos_home_go = Point(x=1099, y=38)
coord_8186_input_start_date = Point(x=137, y=173)
coord_8186_input_end_date = Point(x=319, y=176)
coord_8186_input_fund_code = Point(x=505, y=169)
coord_8186_fund_go = Point(x=540, y=173)
coord_8186_fund_popup_checkbox = Point(x=258, y=604)
coord_8186_fund_popup_confirm = Point(x=620, y=1078)
coord_8186_search_go = Point(x=1168, y=126)
coord_8186_excel_go = Point(x=1240, y=240)
coord_home_logo = Point(x=100, y=34)
coord_2160_input_fund_code = Point(x=107, y=175)
coord_2160_input_start_date = Point(x=535, y=175)
coord_2160_input_end_date = Point(x=630, y=175)
coord_2160_search_go = coord_8186_search_go
coord_2160_excel_go = Point(x=1152, y=219)
coord_2160_excel_format_popup_button = Point(x=1033, y=367)
coord_2205_input_fund_code = Point(x=113, y=211)
coord_2205_input_reference_date = Point(x=114, y=241)
coord_2205_search_go = coord_8186_search_go
coord_2205_excel_go = Point(x=1157, y=304)
coord_2205_excel_format_popup_button =Point(x=1035, y=464)

# key constants
key_save_as_windows = 'F12'
# file_name = f'menu{menu_code}-code{fund_code}-save{get_today()}.csv'
file_format_select_key = 'c'
folder_path = "C:\\rpa-download-datasets"


def get_today():
    return datetime.datetime.now().strftime('%Y%m%d%H%M')

def wait_for_loading_to_disappear(loading_image, timeout=300):
    """
    loading_image: 로딩 화면의 스크린샷 파일 경로 (예: 'loading.png')
    timeout: 함수가 지정한 시간(초) 동안 로딩 화면이 사라지지 않으면 중단 (기본값: 5분)
    """
    start_time = time.time()
    
    while True:
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print("Timeout! Loading screen did not disappear within the specified time.")
            return False
        
        # locateOnScreen 함수를 사용하여 로딩 화면이 화면에 있는지 확인
        location = pyautogui.locateOnScreen(loading_image, confidence=0.8)
        if location is None:
            return True
        
        # 로딩 화면이 화면에 있으면 잠시 대기 후 다시 확인
        time.sleep(1)

def click_image(image_path, confidence_level=0.8, timeout=10):
    """
    image_path: 찾고자 하는 이미지의 파일 경로
    confidence_level: 이미지 탐색 정확도 (0 ~ 1 사이의 값)
    timeout: 이미지 탐색 최대 대기 시간 (초)
    
    이미지를 찾으면 그 위치를 클릭하고 True를 반환하고, 찾지 못하면 False를 반환한다.
    """
    start_time = time.time()
    while True:
        location = pyautogui.locateCenterOnScreen(image_path, confidence=confidence_level)
        if location:
            pyautogui.click(location)
            return True
        
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print(f"Timeout! Could not find the image '{image_path}' within {timeout} seconds.")
            return False
        
        time.sleep(1)

def moveTo_image(image_path, confidence_level=0.8, timeout=10):
    """
    image_path: 찾고자 하는 이미지의 파일 경로
    confidence_level: 이미지 탐색 정확도 (0 ~ 1 사이의 값)
    timeout: 이미지 탐색 최대 대기 시간 (초)
    
    이미지를 찾으면 그 위치를 클릭하고 True를 반환하고, 찾지 못하면 False를 반환한다.
    """
    start_time = time.time()
    while True:
        location = pyautogui.locateCenterOnScreen(image_path, confidence=confidence_level)
        if location:
            pyautogui.moveTo(location)
            return True
        
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print(f"Timeout! Could not find the image '{image_path}' within {timeout} seconds.")
            return False
        
        time.sleep(1)

def is_image_present(image_path, confidence_level=0.8, timeout=2):
    """
    image_path: 찾고자 하는 이미지의 파일 경로
    confidence_level: 이미지 탐색 정확도 (0 ~ 1 사이의 값)
    timeout: 이미지 탐색 최대 대기 시간 (초)
    
    이미지를 찾으면 True를 반환하고, 찾지 못하면 False를 반환한다.
    """
    start_time = time.time()
    while True:
        location = pyautogui.locateOnScreen(image_path, confidence=confidence_level)
        if location:
            return True
        
        # 현재 시간과 시작 시간의 차이가 timeout보다 크면 종료
        if time.time() - start_time > timeout:
            print(f"- Timeout! Could not find the image '{image_path}' within {timeout} seconds.")
            return False
        
        time.sleep(1)

def ____cooltime(t=time_cooldown):
    time.sleep(t)
    return None

def wait_loading():
    if is_image_present('image-8186-loading.png', timeout=1):
        print('step: wait loading...')
        if wait_for_loading_to_disappear('image-8186-loading.png', timeout=300):
            return True
        else:
            print('Error: loading screen did not disappear within the specified time.')
            return False 
    else:
        return True

def wait_execution():
    if is_image_present('image-excel-header.png', timeout=30):
        return True
    else:
        return False

def control_from_home_to_menu(menu_code):
    print(f'- step: open menu: {menu_code}')
    click(coord_home_input_menu)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(menu_code))
    time.sleep(time_interval_l)
    press('enter')
    time.sleep(time_interval_l)
    # click(coord_home_menu_name)
    # time.sleep(time_interval)
    # click(coord_bos_home_go)
    # time.sleep(time_interval)

# 8186
def control_on_8186_to_fund_popup(start_date, end_date, fund_code):
    print(f'- step: open fund popup.')
    click(coord_8186_input_start_date)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(start_date))
    time.sleep(time_interval)
    click(coord_8186_input_end_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(end_date))
    time.sleep(time_interval)
    click(coord_8186_input_fund_code)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(fund_code)
    time.sleep(time_interval)
    click(coord_8186_fund_go)
    time.sleep(time_interval_l)

def control_on_fund_popup():
    print(f'- step: select fund on popup.')
    time.sleep(time_interval)
    click(coord_8186_fund_popup_checkbox)
    time.sleep(time_interval)
    click(coord_8186_fund_popup_confirm)

def control_on_8186_to_excel():
    print(f'- step: load system dataset.')
    time.sleep(time_interval)
    click(coord_8186_search_go)
    time.sleep(time_interval)
    # 로딩 화면이 사라질 때까지 기다린다.
    if wait_for_loading_to_disappear('image-8186-loading.png'):
        # 로딩 화면이 사라지면 특정 좌표를 클릭
        print(f'- step: execute Excel.')
        click(coord_8186_excel_go)
    time.sleep(time_interval_loading)

def control_on_excel_to_save_as_popup():
    print(f'- step: open save as popup.')
    time.sleep(time_interval_loading)
    press(key_save_as_windows)
    ____sleep(time_cooldown)

def control_on_save_as_popup(file_name, folder_path):
    print(f'- step: input save settings.')
    typewrite(file_name)
    time.sleep(time_interval)
    press('tab')
    ____sleep(time_interval)
    typewrite(file_format_select_key)
    time.sleep(time_interval_loading)
    moveTo_image('image-excel-folder-arrows.png')
    time.sleep(time_interval_l)
    move(screen_width/5,0)
    click()
    time.sleep(time_interval_l)
    typewrite(folder_path)
    time.sleep(time_interval_l)
    hotkey('alt', 's')
    if is_image_present('icon-caution-save-as.png', timeout=1):
        hotkey('alt', 'y')
    time.sleep(time_interval)

def close_excel_and_goto_home():
    print(f'- step: terminate Excel.')
    # click_image('image-excel-header.png', timeout=30)
    ____cooltime()
    if is_image_present('image-excel-header.png', timeout=30):
        hotkey('alt', 'F4')
    click(coord_home_logo)
    print(f'- step: return to home.')

# 2160
def control_on_2160_to_set_inputs(fund_code, start_date, end_date):
    print(f'- step: set inputs.')
    click(coord_2160_input_fund_code)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(fund_code))

    time.sleep(time_interval)
    click(coord_2160_input_start_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(start_date))
    
    time.sleep(time_interval)
    click(coord_2160_input_end_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(end_date))

    time.sleep(time_interval)
    click(coord_2160_search_go)
    time.sleep(time_interval_l)

def control_on_2160_to_excel():
    print(f'- step: click excel download button.')
    time.sleep(time_interval_l)
        # 로딩 화면이 사라질 때까지 기다린다.
    if wait_for_loading_to_disappear('image-8186-loading.png'):
    # 로딩 화면이 사라지면 특정 좌표를 클릭
        print(f'- step: execute Excel.')
        click(coord_2160_excel_go)
        time.sleep(time_interval_l)
        click(coord_2160_excel_format_popup_button)
    time.sleep(time_interval_loading)
    time.sleep(10)

#2205
def control_on_2205_to_set_inputs(fund_code, end_date):
    reference_date = end_date
    print(f'- step: set inputs.')
    click(coord_2205_input_fund_code)
    time.sleep(time_interval)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(fund_code))

    time.sleep(time_interval)
    click(coord_2205_input_reference_date)
    hotkey('ctrl', 'a')
    press('backspace')
    time.sleep(time_interval)
    typewrite(list(reference_date))

    time.sleep(time_interval)
    click(coord_2205_search_go)
    time.sleep(time_interval_l)

def control_on_2205_to_excel():
    print(f'- step: click excel download button.')
    time.sleep(time_interval_l)
        # 로딩 화면이 사라질 때까지 기다린다.
    if wait_for_loading_to_disappear('image-8186-loading.png'):
    # 로딩 화면이 사라지면 특정 좌표를 클릭
        print(f'- step: execute Excel.')
        click(coord_2205_excel_go)
        time.sleep(time_interval_l)
        click(coord_2205_excel_format_popup_button)
    time.sleep(time_interval_loading)
    time.sleep(10)

class BOS:
    def __init__(self, fund_code, end_date, start_date='20210101'):
        self.fund_code = fund_code
        self.start_date = start_date
        self.end_date = end_date
        self.menu_code = None

    def goto_menu(self, menu_code):
        self.menu_code = menu_code
        control_from_home_to_menu(self.menu_code)
        wait_loading()
        return self

    def download_dataset(self):
        self.download_dataset_8186(),

    def download_dataset_8186(self):
        control_on_8186_to_fund_popup(self.start_date, self.end_date, self.fund_code)
        wait_loading()
        control_on_fund_popup()
        wait_loading()
        control_on_8186_to_excel()
        wait_execution()
        control_on_excel_to_save_as_popup()
        wait_loading()
        self.file_name = f'menu{self.menu_code}-code{self.fund_code}-save{get_today()}.csv'
        self.folder_path = folder_path
        control_on_save_as_popup(self.file_name, self.folder_path)
        wait_loading()
        close_excel_and_goto_home()
        print(f'- save complete: {self.file_name} in {self.folder_path}')

class MOS(BOS):
    def download_dataset(self):
        mapping = {
            '2160': self.download_dataset_2160(),
            '2205': self.download_dataset_2205()
        }
        mapping[self.menu_code]

    def download_dataset_2160(self):
        control_on_2160_to_set_inputs(self.fund_code, self.start_date, self.end_date)
        wait_loading()
        control_on_2160_to_excel()
        wait_execution()
        control_on_excel_to_save_as_popup()
        wait_loading()
        self.file_name = f'menu{self.menu_code}-code{self.fund_code}-save{get_today()}.csv'
        self.folder_path = folder_path
        control_on_save_as_popup(self.file_name, self.folder_path)
        wait_loading()
        close_excel_and_goto_home()
        print(f'- save complete: {self.file_name} in {self.folder_path}')

    def download_dataset_2205(self):
        control_on_2205_to_set_inputs(self.fund_code, self.end_date)
        wait_loading()
        control_on_2205_to_excel()
        wait_execution()
        control_on_excel_to_save_as_popup()
        wait_loading()
        reference_date = self.end_date
        self.file_name = f'menu{self.menu_code}-code{self.fund_code}-date{reference_date}-save{get_today()}.csv'
        self.folder_path = folder_path
        control_on_save_as_popup(self.file_name, self.folder_path)
        wait_loading()
        close_excel_and_goto_home()
        print(f'- save complete: {self.file_name} in {self.folder_path}')

# %%
for i, code in enumerate(fund_codes_october):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    BOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('8186').download_dataset_2160()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")

# %%
for i, code in enumerate(fund_codes_october):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2160').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) 000051
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code000051-save202311051647.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.660227
# - (2/30) 000052
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code000052-save202311051649.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.706013
# - (3/30) 100001
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# Timeout! Could not find the image 'image-excel-folder-arrows.png' within 10 seconds.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100001-save202311051650.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:24.420039
# - (4/30) 100004
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100004-save202311051651.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:12.145536
# - (5/30) 100008
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100008-save202311051652.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.988596
# - (6/30) 100019
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100019-save202311051654.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:11.099903
# - (7/30) 100030
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100030-save202311051655.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.939316
# - (8/30) 100038
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100038-save202311051656.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.997857
# - (9/30) 100042
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100042-save202311051657.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.814758
# - (10/30) 100050
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100050-save202311051658.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.842019
# - (11/30) 100056
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100056-save202311051659.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.780302
# - (12/30) 100059
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100059-save202311051701.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.681493
# - (13/30) 100060
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100060-save202311051702.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.817214
# - (14/30) 100065
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100065-save202311051703.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.719027
# - (15/30) 100066
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100066-save202311051704.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.761506
# - (16/30) 100069
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100069-save202311051705.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.808295
# - (17/30) 100073
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100073-save202311051706.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.837583
# - (18/30) 100077
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100077-save202311051708.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.730134
# - (19/30) 100078
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100078-save202311051709.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.790782
# - (20/30) 100079
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100079-save202311051710.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.729753
# - (21/30) 805701
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code805701-save202311051711.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.758706
# - (22/30) 805702
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code805702-save202311051712.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.799202
# - (23/30) 805703
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code805703-save202311051713.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.696141
# - (24/30) 805704
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code805704-save202311051715.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.771336
# - (25/30) A00001
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-codeA00001-save202311051716.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.766972
# - (26/30) A00002
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 34 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=1'>2</a> print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.datetime.now()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=3'>4</a> MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2160').download_dataset_2160()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=4'>5</a> end_time = datetime.datetime.now()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=5'>6</a> elapsed_time = end_time - start_time
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 34 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=386'>387</a> control_on_save_as_popup(self.file_name, self.folder_path)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=387'>388</a> wait_loading()
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=388'>389</a> close_excel_and_goto_home()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=389'>390</a> print(f'- save complete: {self.file_name} in {self.folder_path}')
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 34 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=257'>258</a> print(f'- step: terminate Excel.')
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=258'>259</a> # click_image('image-excel-header.png', timeout=30)
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=259'>260</a> ____cooltime()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=260'>261</a> if is_image_present('image-excel-header.png', timeout=30):
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=261'>262</a>     hotkey('alt', 'F4')
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 34 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=149'>150</a> def ____cooltime(t=time_cooldown):
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=150'>151</a>     time.sleep(t)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#Y110sZmlsZQ%3D%3D?line=151'>152</a>     return None
#
# KeyboardInterrupt:

# %%
for i, code in enumerate(["A00002", "A00003", "A00004", "A00005"]):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2160').download_dataset_2160()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) A00002
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-codeA00002-save202311051720.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.762723
# - (2/30) A00003
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-codeA00003-save202311051721.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.772318
# - (3/30) A00004
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-codeA00004-save202311051723.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.671190
# - (4/30) A00005
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-codeA00005-save202311051724.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.690651

# %%
mos = MOS(fund_code='805701', start_date='20210101', end_date='20231031').goto_menu('2205').download_dataset()
# Out:
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code805701-date20231031-save202311051633.csv in C:\rpa-download-datasets

# %%
control_on_2205_to_set_inputs('100004', '20231031')
# Out:
# - step: set inputs.

# %%
control_on_2205_to_excel()
# Out:
# - step: click excel download button.
# - step: execute Excel.

# %%
control_from_home_to_menu('2205')
# Out:
# - step: open menu: 2205

# %%
position()
# Out:
# Point(x=114, y=241)

# %%
mos = MOS(fund_code='100078', start_date='20210101', end_date='20231031').goto_menu('2160').download_dataset_2160()
# Out:
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100078-save202311051729.csv in C:\rpa-download-datasets

# %%
mos.fund_code
# Out:
# '100004'

# %%
BOS(fund_code='100002', start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: select fund on popup.
# - step:: load system dataset.
# - step:: execute Excel.
# - step:: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: terminate Excel.
# - step:: return to home.
# - save complete: menu8186-code100002-save202311021508.csv in C:\rpa-download-datasets

# %%
BOS(fund_code='100008', start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
BOS(fund_code='100030', start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: select fund on popup.
# - step:: load system dataset.
# - step:: execute Excel.
# - step:: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: terminate Excel.
# - step:: return to home.
# - save complete: menu8186-code100008-save202311021511.csv in C:\rpa-download-datasets
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: select fund on popup.
# - step:: load system dataset.
# - step:: execute Excel.
# - step:: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step:: terminate Excel.
# - step:: return to home.
# - save complete: menu8186-code100030-save202311021512.csv in C:\rpa-download-datasets

# %%
BOS(fund_code='100065', start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: load system dataset.
# - step: execute Excel.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 45 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> BOS(fund_code='100065', start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 45 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=354'>355</a> def download_dataset(self):
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=355'>356</a>     self.download_dataset_8186(),
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 45 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=360'>361</a> control_on_fund_popup()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=361'>362</a> wait_loading()
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=362'>363</a> control_on_8186_to_excel()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=363'>364</a> wait_execution()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=364'>365</a> control_on_excel_to_save_as_popup()
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 45 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=226'>227</a>     print(f'- step: execute Excel.')
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=227'>228</a>     click(coord_8186_excel_go)
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X51sZmlsZQ%3D%3D?line=228'>229</a> time.sleep(time_interval_loading)
#
# KeyboardInterrupt:

# %%
codes = [
    "000051", "000052", "100001", "100004", "100008", "100019", "100030",
    "100038", "100042", "100050", "100056", "100059", "100060", "100065",
    "100066", "100069", "100073", "100077", "100078", "100079", "805701",
    "805702", "805703", "805704", "A00001", "A00002", "A00003", "A00004", "A00005"
]

# %%
for i, code in enumerate(fund_codes_october):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2205').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) 000051
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000051-date20231031-save202311051547.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.407408
# - (2/30) 000052
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000052-date20231031-save202311051548.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.434333
# - (3/30) 100001
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100001-date20231031-save202311051549.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.675081
# - (4/30) 100004
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100004-date20231031-save202311051550.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.495609
# - (5/30) 100008
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100008-date20231031-save202311051552.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.636899
# - (6/30) 100019
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100019-date20231031-save202311051553.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.443540
# - (7/30) 100030
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100030-date20231031-save202311051554.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.438281
# - (8/30) 100038
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100038-date20231031-save202311051555.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.296973
# - (9/30) 100042
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100042-date20231031-save202311051556.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.480677
# - (10/30) 100050
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100050-date20231031-save202311051557.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.525892
# - (11/30) 100056
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100056-date20231031-save202311051558.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.521136
# - (12/30) 100059
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100059-date20231031-save202311051559.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.441133
# - (13/30) 100060
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100060-date20231031-save202311051601.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.449166
# - (14/30) 100065
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100065-date20231031-save202311051602.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.353464
# - (15/30) 100066
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100066-date20231031-save202311051603.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.498375
# - (16/30) 100069
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100069-date20231031-save202311051604.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.506850
# - (17/30) 100073
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100073-date20231031-save202311051605.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.517410
# - (18/30) 100077
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100077-date20231031-save202311051606.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.659510
# - (19/30) 100078
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100078-date20231031-save202311051607.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.510346
# - (20/30) 100079
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# Timeout! Could not find the image 'image-excel-folder-arrows.png' within 10 seconds.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.

# %%
for i, code in enumerate(fund_codes_october):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2205').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) 000051
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000051-date20231031-save202311051547.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.407408
# - (2/30) 000052
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000052-date20231031-save202311051548.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.434333
# - (3/30) 100001
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100001-date20231031-save202311051549.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.675081
# - (4/30) 100004
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100004-date20231031-save202311051550.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.495609
# - (5/30) 100008
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100008-date20231031-save202311051552.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.636899
# - (6/30) 100019
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100019-date20231031-save202311051553.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.443540
# - (7/30) 100030
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100030-date20231031-save202311051554.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.438281
# - (8/30) 100038
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100038-date20231031-save202311051555.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.296973
# - (9/30) 100042
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100042-date20231031-save202311051556.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.480677
# - (10/30) 100050
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100050-date20231031-save202311051557.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.525892
# - (11/30) 100056
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100056-date20231031-save202311051558.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.521136
# - (12/30) 100059
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100059-date20231031-save202311051559.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.441133
# - (13/30) 100060
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100060-date20231031-save202311051601.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.449166
# - (14/30) 100065
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100065-date20231031-save202311051602.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.353464
# - (15/30) 100066
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100066-date20231031-save202311051603.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.498375
# - (16/30) 100069
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100069-date20231031-save202311051604.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.506850
# - (17/30) 100073
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100073-date20231031-save202311051605.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.517410
# - (18/30) 100077
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100077-date20231031-save202311051606.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.659510
# - (19/30) 100078
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100078-date20231031-save202311051607.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.510346
# - (20/30) 100079
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# Timeout! Could not find the image 'image-excel-folder-arrows.png' within 10 seconds.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.

# %%
for i, code in enumerate(fund_codes_october):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2205').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) 000051
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000051-date20231031-save202311051547.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.407408
# - (2/30) 000052
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code000052-date20231031-save202311051548.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.434333
# - (3/30) 100001
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100001-date20231031-save202311051549.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.675081
# - (4/30) 100004
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100004-date20231031-save202311051550.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.495609
# - (5/30) 100008
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100008-date20231031-save202311051552.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.636899
# - (6/30) 100019
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100019-date20231031-save202311051553.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.443540
# - (7/30) 100030
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100030-date20231031-save202311051554.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.438281
# - (8/30) 100038
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100038-date20231031-save202311051555.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.296973
# - (9/30) 100042
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100042-date20231031-save202311051556.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.480677
# - (10/30) 100050
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100050-date20231031-save202311051557.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.525892
# - (11/30) 100056
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100056-date20231031-save202311051558.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.521136
# - (12/30) 100059
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100059-date20231031-save202311051559.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.441133
# - (13/30) 100060
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100060-date20231031-save202311051601.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.449166
# - (14/30) 100065
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100065-date20231031-save202311051602.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.353464
# - (15/30) 100066
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100066-date20231031-save202311051603.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.498375
# - (16/30) 100069
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100069-date20231031-save202311051604.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.506850
# - (17/30) 100073
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100073-date20231031-save202311051605.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.517410
# - (18/30) 100077
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100077-date20231031-save202311051606.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.659510
# - (19/30) 100078
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100078-date20231031-save202311051607.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.510346
# - (20/30) 100079
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# Timeout! Could not find the image 'image-excel-folder-arrows.png' within 10 seconds.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 50 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.datetime.now()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a> MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2205').download_dataset()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a> end_time = datetime.datetime.now()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a> elapsed_time = end_time - start_time
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 50 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=374'>375</a> def download_dataset(self):
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=375'>376</a>     self.download_dataset_2205()
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 50 line 4
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=401'>402</a> control_on_save_as_popup(self.file_name, self.folder_path)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=402'>403</a> wait_loading()
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=403'>404</a> close_excel_and_goto_home()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=404'>405</a> print(f'- save complete: {self.file_name} in {self.folder_path}')
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 50 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=257'>258</a> print(f'- step: terminate Excel.')
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=258'>259</a> # click_image('image-excel-header.png', timeout=30)
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=259'>260</a> ____cooltime()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=260'>261</a> if is_image_present('image-excel-header.png', timeout=30):
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=261'>262</a>     hotkey('alt', 'F4')
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 50 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=149'>150</a> def ____cooltime(t=time_cooldown):
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=150'>151</a>     time.sleep(t)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X53sZmlsZQ%3D%3D?line=151'>152</a>     return None
#
# KeyboardInterrupt:

# %%
fund_codes_october
# Out:
# ['000051',
#  '000052',
#  '100001',
#  '100004',
#  '100008',
#  '100019',
#  '100030',
#  '100038',
#  '100042',
#  '100050',
#  '100056',
#  '100059',
#  '100060',
#  '100065',
#  '100066',
#  '100069',
#  '100073',
#  '100077',
#  '100078',
#  '100079',
#  '805701',
#  '805702',
#  '805703',
#  '805704',
#  'A00001',
#  'A00002',
#  'A00003',
#  'A00004',
#  'A00005']

# %%
for i, code in enumerate(['100079',
 '805701',
 '805702',
 '805703',
 '805704',
 'A00001',
 'A00002',
 'A00003',
 'A00004',
 'A00005']):
    print(f"- ({i+1}/{len(fund_codes_october)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date=start_date_default, end_date=end_date_october).goto_menu('2205').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/30) 100079
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code100079-date20231031-save202311051612.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.469386
# - (2/30) 805701
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code805701-date20231031-save202311051613.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.460332
# - (3/30) 805702
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code805702-date20231031-save202311051614.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.456192
# - (4/30) 805703
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code805703-date20231031-save202311051615.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.433205
# - (5/30) 805704
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-code805704-date20231031-save202311051616.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.483508
# - (6/30) A00001
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-codeA00001-date20231031-save202311051617.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.571225
# - (7/30) A00002
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-codeA00002-date20231031-save202311051618.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.724832
# - (8/30) A00003
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-codeA00003-date20231031-save202311051620.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.795545
# - (9/30) A00004
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-codeA00004-date20231031-save202311051621.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.714228
# - (10/30) A00005
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2205-codeA00005-date20231031-save202311051622.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.769933

# %%
2160
# Out:
# - (0/29) 000051
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code000051-save202311021537.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:36.740335
# - (1/29) 000052
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> print(f"- ({i}/{len(codes)}) {code}")
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.datetime.now()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> BOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=4'>5</a> end_time = datetime.datetime.now()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> elapsed_time = end_time - start_time
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=253'>254</a> def download_dataset(self):
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=254'>255</a>     mapping={
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=255'>256</a>         '8186': self.download_dataset_8186()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=256'>257</a>     }
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=257'>258</a>     return mapping[self.menu_code]
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=264'>265</a> control_on_8186_to_excel()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=265'>266</a> wait_execution()
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=266'>267</a> control_on_excel_to_save_as_popup()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=267'>268</a> wait_loading()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=268'>269</a> self.file_name = f'menu{self.menu_code}-code{self.fund_code}-save{get_today()}.csv'
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=206'>207</a> time.sleep(time_interval_loading)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=207'>208</a> press(key_save_as_windows)
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=208'>209</a> ____sleep(time_cooldown)
#
# KeyboardInterrupt:

# %%
for i, code in enumerate(codes):
    print(f"- ({i+1}/{len(codes)+1}) {code}")
    start_time = datetime.datetime.now()
    BOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (0/29) 000051
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code000051-save202311021537.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:36.740335
# - (1/29) 000052
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 4
#
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> print(f"- ({i}/{len(codes)}) {code}")
#
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.datetime.now()
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> BOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=4'>5</a> end_time = datetime.datetime.now()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> elapsed_time = end_time - start_time
#
#
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=253'>254</a> def download_dataset(self):
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=254'>255</a>     mapping={
#
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=255'>256</a>         '8186': self.download_dataset_8186()
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=256'>257</a>     }
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=257'>258</a>     return mapping[self.menu_code]
#
#
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=264'>265</a> control_on_8186_to_excel()
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=265'>266</a> wait_execution()
#
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=266'>267</a> control_on_excel_to_save_as_popup()
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=267'>268</a> wait_loading()
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=268'>269</a> self.file_name = f'menu{self.menu_code}-code{self.fund_code}-save{get_today()}.csv'
#
#
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 36 line 2
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=206'>207</a> time.sleep(time_interval_loading)
#
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=207'>208</a> press(key_save_as_windows)
#
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X52sZmlsZQ%3D%3D?line=208'>209</a> ____sleep(time_cooldown)
#
#
#
# KeyboardInterrupt:

# %%
codes_todo = [
    "100038", "100042", "100050", "100065",
    "100066", "100069", "100073", "100077", "100078", "100079", "805701",
    "805702", "805703", "805704", "A00001", "A00002", "A00003", "A00004", "A00005"
]

# %%
for i, code in enumerate(codes_todo):
    print(f"- ({i+1}/{len(codes_todo)+1}) {code}")
    start_time = datetime.datetime.now()
    BOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('8186').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/22) 100038
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100038-save202311021610.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:16.802372
# - (2/22) 100042
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100042-save202311021611.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.493352
# - (3/22) 100050
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100050-save202311021612.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:07.178261
# - (4/22) 100056
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100056-save202311021613.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:06.341980
# - (5/22) 100059
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100059-save202311021614.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.413772
# - (6/22) 100065
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: return to home.
# - save complete: menu8186-code100065-save202311021616.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:36.383350
# - (7/22) 100066
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100066-save202311021617.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:05.588377
# - (8/22) 100069
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100069-save202311021618.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:04.951451
# - (9/22) 100073
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100073-save202311021619.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:06.345970
# - (10/22) 100077
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100077-save202311021620.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:05.905621
# - (11/22) 100078
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100078-save202311021622.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:05.289918
# - (12/22) 100079
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code100079-save202311021623.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:07.075658
# - (13/22) 805701
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code805701-save202311021624.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:06.620213
# - (14/22) 805702
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code805702-save202311021625.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:09.623090
# - (15/22) 805703
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code805703-save202311021626.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:14.081219
# - (16/22) 805704
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-code805704-save202311021627.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.214967
# - (17/22) A00001
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-codeA00001-save202311021628.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:08.641133
# - (18/22) A00002
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-codeA00002-save202311021630.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:05.502816
# - (19/22) A00003
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-codeA00003-save202311021631.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.834677
# - (20/22) A00004
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-codeA00004-save202311021632.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:27.909059
# - (21/22) A00005
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: oepn fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: load system dataset.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu8186-codeA00005-save202311021633.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:17.543716

# %%
codes = ["100065", "100069", "100073", "100077", "100078", "100079", "805701",
    "805702", "805703", "805704", "A00001", "A00002", "A00003", "A00004", "A00005"
]

# %%
for i, code in enumerate(codes):
    print(f"- ({i+1}/{len(codes)+1}) {code}")
    start_time = datetime.datetime.now()
    MOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('2160').download_dataset()
    end_time = datetime.datetime.now()
    elapsed_time = end_time - start_time
    print(f"-- elapsed time: {elapsed_time}")
# Out:
# - (1/16) 100065
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100065-save202311031514.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.085726
# - (2/16) 100069
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100069-save202311031515.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.123066
# - (3/16) 100073
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100073-save202311031517.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.196966
# - (4/16) 100077
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100077-save202311031518.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.045512
# - (5/16) 100078
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: terminate Excel.
# - step: return to home.
# - save complete: menu2160-code100078-save202311031519.csv in C:\rpa-download-datasets
# -- elapsed time: 0:01:10.105404
# - (6/16) 100079
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 46 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> print(f"- ({i+1}/{len(codes)+1}) {code}")
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.datetime.now()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> MOS(fund_code=code, start_date='20210101', end_date='20231030').goto_menu('2160').download_dataset()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> end_time = datetime.datetime.now()
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> elapsed_time = end_time - start_time
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 46 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=325'>326</a> def download_dataset(self):
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=326'>327</a>     mapping={
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=327'>328</a>         '2160': self.download_dataset_2160()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=328'>329</a>     }
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=329'>330</a>     return mapping[self.menu_code]
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 46 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=332'>333</a> control_on_2160_to_set_inputs(self.fund_code, self.start_date, self.end_date)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=333'>334</a> wait_loading()
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=334'>335</a> control_on_2160_to_excel()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=335'>336</a> wait_execution()
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=336'>337</a> control_on_excel_to_save_as_popup()
#
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\pyautogui-test.ipynb Cell 46 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=283'>284</a>     click(coord_excel_format_popup_button)
#     <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=284'>285</a> time.sleep(time_interval_loading)
# --> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/pyautogui-test.ipynb#X62sZmlsZQ%3D%3D?line=285'>286</a> time.sleep(10)
#
# KeyboardInterrupt:
