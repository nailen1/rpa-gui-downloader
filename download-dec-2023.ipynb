# %%
from DownloadAutomation import *
import DownloadAutomation

import importlib
importlib.reload(DownloadAutomation)
# Out:
# <module 'DownloadAutomation' from 'c:\\Users\\danie\\Documents\\dev-windows\\rpa-gui-control\\DownloadAutomation.py'>

# %%
for code in ['000051', '100001', '100004', '100008', '100019',
       '100030', '100038', '100042', '100050', '100056', '100059',
       '100060', '100065', '100066', '100069', '100073', '100077',
       '100078', '100079', '805701', '805702', '805703', '805704',
       'A00001', 'A00002', 'A00003', 'A00004', 'A00005']:
    MOS(fund_code=code, start_date='20231201', end_date='20231231').goto_menu('2305').download_dataset()
# Out:
# - step: open menu: 2305
# - step: wait loading...
# - is dataset regex 'menu2305-code000051-date20231201_20231231-save20240103' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - yes: 000051 in C:\rpa-download-datasets-DEC2023
# - step: terminate Microsoft Excel.
# - step: open menu: 2305
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2305-code100001-date20231201_20231231-save20240103' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 100001 not in C:\rpa-download-datasets-DEC2023
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# ...

# %%
today = get_today(form='yyyy-mm-dd')
today
# Out:
# '2024-01-03'

# %%
end_date_dec = '20231231'

# %%
len(fund_codes_nov)
# Out:
# 33

# %%
for code in fund_codes_nov:
    BOS(fund_code=code, start_date='20210101', end_date=today).goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000038-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-DEC2023
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: wait loading...
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 5 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000038-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# ...

# %%
for code in fund_codes_nov:
    MOS(fund_code=code, start_date='20210101', end_date=end_date_dec).goto_menu('2160').download_dataset()
# Out:
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000038-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-DEC2023
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000038-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - yes: 000038 in C:\rpa-download-datasets-DEC2023
# - step: terminate Microsoft Excel.
# - save complete: menu2160-code000038-save20240102.csv in C:\rpa-download-datasets-DEC2023
# - step: return to home.
# ...

# %%
for code in fund_codes_nov:
    MOS(fund_code=code, start_date='20231201', end_date=end_date_dec).goto_menu('2205').download_dataset()
# Out:
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2205-code000038-date20231231-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-DEC2023
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 10 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2205-code000038-date20231231-save20240102' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-DEC2023
# - step: set inputs.
# ...

# %% [markdown]
# # 2820 FULL

# %%
for code in fund_codes_nov:
    MOS(fund_code=code, start_date='20210101', end_date='20240102').goto_menu('2820').download_dataset()
# Out:
# - step: open menu: 2820
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2820-code000038-save20240103' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-DEC2023
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2820-code000038-save20240103' at 'C:\rpa-download-datasets-DEC2023' downloaded?
# - yes: 000038 in C:\rpa-download-datasets-DEC2023
# -  complete: menu2820-code000038-save20240103.csv in C:\rpa-download-datasets-DEC2023
# - step: terminate Microsoft Excel.
# ...
