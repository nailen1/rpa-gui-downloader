# %%
import DownloadAutomation as da
import DownloadAutomation
from DownloadAutomation import BOS
from DownloadAutomation import MOS
import os
import pandas as pd
import numpy as np

import importlib
importlib.reload(DownloadAutomation)
importlib.reload(da)
# Out:
# <module 'DownloadAutomation' from 'c:\\Users\\danie\\Documents\\dev-windows\\rpa-gui-control\\DownloadAutomation.py'>

# %%
# 일단 10월 기준으로 다운로드

fund_codes_october = [
    "000051", "000052", "100001", "100004", "100008", "100019", "100030",
    "100038", "100042", "100050", "100056", "100059", "100060", "100065",
    "100066", "100069", "100073", "100077", "100078", "100079", "805701",
    "805702", "805703", "805704", "A00001", "A00002", "A00003", "A00004", "A00005"
]


fund_codes_np = [
    "000038", '000039', '000045', '000053', '100001', '100019', '100030', '100060', '100066'
]

# %%
end_date_nov = '20231130'

# %% [markdown]
# # 8186

# %%
for code in fund_codes_october:
    BOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000051-save20231201' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000051 not in C:\rpa-download-datasets-2023NOV
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: wait loading...
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 5 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000051-save20231201' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# ...

# %%
for code in fund_codes_np:
    BOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000038-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-2023NOV
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: wait loading...
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 5 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000038-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# ...

# %%
import os
lst = []
with os.scandir('C:/rpa-download-datasets-2023NOV') as files:
    for file in files:
        if file.name.endswith('.csv'):
            lst.append(file.name)
lst
# Out:
# ['menu8186-code000051-save202312011545.csv',
#  'menu8186-code000052-save202312011547.csv',
#  'menu8186-code100001-save202312011548.csv',
#  'menu8186-code100004-save202312011550.csv',
#  'menu8186-code100008-save202312011553.csv',
#  'menu8186-code100019-save202312011554.csv',
#  'menu8186-code100030-save202312011558.csv',
#  'menu8186-code100038-save202312011600.csv',
#  'menu8186-code100042-save202312011602.csv',
#  'menu8186-code100050-save202312011603.csv',
#  'menu8186-code100056-save202312011605.csv',
#  'menu8186-code100059-save202312011606.csv',
#  'menu8186-code100060-save202312011608.csv',
#  'menu8186-code100065-save202312011609.csv',
#  'menu8186-code100066-save202312011611.csv',
#  'menu8186-code100069-save202312011612.csv',
#  'menu8186-code100073-save202312011614.csv',
#  'menu8186-code100077-save202312011615.csv',
#  'menu8186-code100078-save202312011617.csv',
#  'menu8186-code100079-save202312011618.csv',
#  'menu8186-code805701-save202312011620.csv',
# ...

# %%
[elm.split('-')[1].replace('code', '') for elm in lst]
# Out:
# ['000051',
#  '000052',
#  '100001',
#  '100004',
#  '100008',
#  '100019',
#  '100030',
#  '100038',
#  '100042',
#  '100050',
#  '100056',
#  '100059',
#  '100060',
#  '100065',
#  '100066',
#  '100069',
#  '100073',
#  '100077',
#  '100078',
#  '100079',
#  '805701',
#  '805702',
#  '805703',
#  '805704',
#  'A00001',
#  'A00002',
#  'A00003',
#  'A00004',
#  'A00005']

# %%
fund_codes_october == [elm.split('-')[1].replace('code', '') for elm in lst]
# Out:
# True

# %%
import os

def check_download_funds(folder_name, fund_list):
    lst = []
    with os.scandir(folder_name) as files:
        for file in files:
            if file.name.endswith('.csv'):
                lst.append(file.name)
    if fund_list == [elm.split('-')[1].replace('code', '') for elm in lst]:
        print('- download success')
    else:

# %% [markdown]
# # 2160

# %%
for code in fund_codes_october:
    MOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('2160').download_dataset()
# Out:
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000051-save20231201' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000051 not in C:\rpa-download-datasets-2023NOV
# - step: set inputs.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'image-excel-header.png' within 30 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# Timeout! Could not find the image 'image-excel-folder-arrows.png' within 10 seconds.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# ...

# %%
for code in fund_codes_np:
    MOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('2160').download_dataset()
# Out:
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000038-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-2023NOV
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000038-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000038 in C:\rpa-download-datasets-2023NOV
# - step: terminate Microsoft Excel.
# - save complete: menu2160-code000038-save202312060945.csv in C:\rpa-download-datasets-2023NOV
# ...

# %% [markdown]
# # 2205

# %%
for code in fund_codes_october:
    MOS(fund_code=code, start_date='20231101', end_date=end_date_nov).goto_menu('2205').download_dataset()
# Out:
# - step: open menu: 2205
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2205-code000051-date20231130-save20231201' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000051 not in C:\rpa-download-datasets-2023NOV
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 10 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2205-code000051-date20231130-save20231201' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000051 in C:\rpa-download-datasets-2023NOV
# - step: terminate Microsoft Excel.
# ...

# %%
for code in fund_codes_np:
    MOS(fund_code=code, start_date='20231101', end_date=end_date_nov).goto_menu('2205').download_dataset()
# Out:
# - step: open menu: 2205
# - step: wait loading...
# - is dataset regex 'menu2205-code000038-date20231130-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000038 not in C:\rpa-download-datasets-2023NOV
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 10 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2205-code000038-date20231130-save20231206' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000038 in C:\rpa-download-datasets-2023NOV
# - step: terminate Microsoft Excel.
# ...

# %% [markdown]
# # 2820

# %%
for code in fund_codes_october:
    MOS(fund_code=code, start_date='20231101', end_date=end_date_nov).goto_menu('2820').download_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\danie\Documents\dev-windows\rpa-gui-control\download-2023NOV.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/download-2023NOV.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> for code in fund_codes_october:
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/dev-windows/rpa-gui-control/download-2023NOV.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>     MOS(fund_code=code, start_date='20231101', end_date=end_date_nov).goto_menu('2820').download_dataset()
#
# NameError: name 'fund_codes_october' is not defined

# %%
df_fundlist = pd.read_csv('./menu2110-save20231204.csv')
df_fundlist
# Out:
#                            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                 펀드명         펀드        매니저      국내외구분
# 1           라이프IPO코스닥벤처전문투자형사모투자신탁제1호     000002        남두우         국내
# 2   라이프IPO코스닥벤처전문투자형사모투자신탁제1호 Class A     000003        남두우         국내
# 3   라이프IPO코스닥벤처전문투자형사모투자신탁제1호 Class C     000004        남두우         국내
# 4                   라이프IPO일반사모투자신탁제2호     000005        남두우         국내
# ..                                ...        ...        ...        ...
# 95                        라이프 ESG형 1호     A00001        강대권         국내
# 96                        라이프 ESG형 2호     A00002        강대권         국내
# 97             VUL종신보험 혼합형(주식_라이프_일반)     A00003        강대권         국내
# 98           VUL종신보험 가치주식형(주식_라이프_일반)     A00004        강대권         국내
# 99                      라이프 주식 SJ 제1호     A00005        강대권         국내
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# ...

# %%
def preprocess_2110(df_2110_raw):
    df = df_2110_raw.iloc[1:, :]
    df.columns = df_2110_raw.iloc[0, :].tolist()
    df = df[['펀드명', '펀드', '설정일', '만기일', '펀드구분', '채권편입비', '주식편입비', '자본금']]
    return df

# %%
df = preprocess_2110(df_fundlist)
df
# Out:
#                                   펀드명      펀드         설정일         만기일  펀드구분  \
# 1           라이프IPO코스닥벤처전문투자형사모투자신탁제1호  000002  2020-08-20  2023-12-20  투자신탁
# 2   라이프IPO코스닥벤처전문투자형사모투자신탁제1호 Class A  000003  2020-08-20  2023-12-20  투자신탁
# 3   라이프IPO코스닥벤처전문투자형사모투자신탁제1호 Class C  000004  2020-08-20  2023-12-20  투자신탁
# 4                   라이프IPO일반사모투자신탁제2호  000005  2020-08-26  0000-01-01  투자신탁
# 5           라이프IPO일반사모투자신탁제2호 Class C  000006  2020-08-26  0000-01-01  투자신탁
# ..                                ...     ...         ...         ...   ...
# 95                        라이프 ESG형 1호  A00001  2023-05-11  0000-01-01  투자일임
# 96                        라이프 ESG형 2호  A00002  2023-05-17  0000-01-01  투자일임
# 97             VUL종신보험 혼합형(주식_라이프_일반)  A00003  2023-06-08  0000-01-01  투자일임
# 98           VUL종신보험 가치주식형(주식_라이프_일반)  A00004  2023-07-05  0000-01-01  투자일임
# 99                      라이프 주식 SJ 제1호  A00005  2023-08-22  0000-01-01  투자일임
#
#    채권편입비  주식편입비             자본금
# ...

# %%
fund_codes = np.array(df['펀드'])
fund_codes
# Out:
# array(['000002', '000003', '000004', '000005', '000006', '000009',
#        '000010', '000011', '000012', '000014', '000018', '000019',
#        '000020', '000021', '000022', '000027', '000028', '000029',
#        '000038', '000039', '000040', '000041', '000042', '000043',
#        '000044', '000045', '000046', '000048', '000050', '000051',
#        '000052', '000053', '000054', '000055', '100001', '100002',
#        '100003', '100004', '100005', '100006', '100007', '100008',
#        '100009', '10000F', '100010', '100011', '100015', '100019',
#        '100020', '100021', '100022', '100023', '100024', '100025',
#        '100030', '100031', '100033', '100034', '100035', '100036',
#        '100037', '100038', '100039', '100042', '100043', '100044',
#        '100048', '10004W', '100050', '100051', '100052', '100056',
#        '100057', '100058', '100059', '100060', '100061', '100064',
#        '100065', '100066', '100067', '100068', '100069', '100070',
# ...

# %% [markdown]
# # 2820 full

# %%
for code in fund_codes:
    MOS(fund_code=code, start_date='20210101', end_date='20231203').goto_menu('2820').download_dataset()
# Out:
# - step: open menu: 2820
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2820-code000002-date20231203-save20231204' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000002 in C:\rpa-download-datasets-2023NOV
# -  complete: menu2820-code000002-date20231203-save202312041348.csv in C:\rpa-download-datasets-2023NOV
# - Microsoft Excel is not in process.
# - step: open menu: 2820
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2820-code000003-date20231203-save20231204' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000003 in C:\rpa-download-datasets-2023NOV
# -  complete: menu2820-code000003-date20231203-save202312041348.csv in C:\rpa-download-datasets-2023NOV
# - Microsoft Excel is not in process.
# - step: open menu: 2820
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# ...

# %%
for code in fund_codes:
    BOS(fund_code=code, start_date='20210101', end_date='20231203').goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000002-save20231204' at 'C:\rpa-download-datasets-8186s' downloaded?
# - no: 000002 not in C:\rpa-download-datasets-8186s
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: wait loading...
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 5 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000002-save20231204' at 'C:\rpa-download-datasets-8186s' downloaded?
# ...

# %%
code = '000045'

# %%
BOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('8186').download_dataset()
# Out:
# - step: open menu: 8186
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000045-save20231207' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000045 not in C:\rpa-download-datasets-2023NOV
# - step: open fund popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: select fund on popup.
# - step: wait loading...
# - step: load system dataset.
# - step: execute Excel.
# - Timeout! Could not find the image 'excel-caution-popup.png' within 5 seconds.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu8186-code000045-save20231207' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# ...

# %%
MOS(fund_code=code, start_date='20210101', end_date=end_date_nov).goto_menu('2160').download_dataset()
MOS(fund_code=code, start_date='20231101', end_date=end_date_nov).goto_menu('2205').download_dataset()
# Out:
# - step: open menu: 2160
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000045-save20231207' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - no: 000045 not in C:\rpa-download-datasets-2023NOV
# - step: set inputs.
# - step: wait loading...
# - step: click excel download button.
# - step: execute Excel.
# - step: open save as popup.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - step: input save settings.
# - Timeout! Could not find the image 'icon-caution-save-as.png' within 1 seconds.
# - Timeout! Could not find the image 'image-8186-loading.png' within 1 seconds.
# - is dataset regex 'menu2160-code000045-save20231207' at 'C:\rpa-download-datasets-2023NOV' downloaded?
# - yes: 000045 in C:\rpa-download-datasets-2023NOV
# - step: terminate Microsoft Excel.
# - save complete: menu2160-code000045-save202312070918.csv in C:\rpa-download-datasets-2023NOV
# ...
